# %%
import os
import codecs
import collections
import numpy as np
from six.moves import cPickle

# This is for loading TEXT!
class TextLoader():
    def __init__(self, data_dir, batch_size, seq_length):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.seq_length = seq_length

        input_file = os.path.join(data_dir, "input.txt")
        vocab_file = os.path.join(data_dir, "vocab.pkl")
        tensor_file = os.path.join(data_dir, "data.npy")

        if not (os.path.exists(vocab_file) and os.path.exists(tensor_file)):
            print("reading text file")
            self.preprocess(input_file, vocab_file, tensor_file)
        else:
            print("loading preprocessed files")
            self.load_preprocessed(vocab_file, tensor_file)
        self.create_batches()
        self.reset_batch_pointer()

    def preprocess(self, input_file, vocab_file, tensor_file):
        with codecs.open(input_file, "r", encoding="utf8") as f:
            data = f.read()
        counter = collections.Counter(data)
        count_pairs = sorted(counter.items(), key=lambda x: -x[1])
        self.chars, _ = zip(*count_pairs)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        with open(vocab_file, 'wb') as f:
            cPickle.dump(self.chars, f)
        self.tensor = np.array(list(map(self.vocab.get, data)))
        np.save(tensor_file, self.tensor)

    def load_preprocessed(self, vocab_file, tensor_file):
        with open(vocab_file, 'rb') as f:
            self.chars = cPickle.load(f)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        self.tensor = np.load(tensor_file)
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

    def create_batches(self):
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))
        self.tensor = self.tensor[:self.num_batches * self.batch_size * self.seq_length]
        xdata = self.tensor
        ydata = np.copy(self.tensor)
        ydata[:-1] = xdata[1:]
        ydata[-1] = xdata[0]
        self.x_batches = np.split(xdata.reshape(self.batch_size, -1), self.num_batches, 1)
        self.y_batches = np.split(ydata.reshape(self.batch_size, -1), self.num_batches, 1)


    def next_batch(self):
        x, y = self.x_batches[self.pointer], self.y_batches[self.pointer]
        self.pointer += 1
        return x, y

    def reset_batch_pointer(self):
        self.pointer = 0

# %%
# -*- coding: utf-8 -*-
# Char-RNN 예제
# Author : solaris33
# Project URL : http://solarisailab.com/archives/2487
# GitHub Repository : https://github.com/solaris33/char-rnn-tensorflow/
# Reference : https://github.com/sherjilozair/char-rnn-tensorflow

import tensorflow as tf
import numpy as np

# 학습에 필요한 설정값들을 지정합니다.
data_dir = 'Documents/My/data/tinyshakespeare'
#data_dir = 'data/linux'
batch_size = 50 # Training : 50, Sampling : 1
seq_length = 50 # Training : 50, Sampling : 1
hidden_size = 128   # 히든 레이어의 노드 개수
learning_rate = 0.002
num_epochs = 2
num_hidden_layers = 2
grad_clip = 5   # Gradient Clipping에 사용할 임계값

# TextLoader를 이용해서 데이터를 불러옵니다.
data_loader = TextLoader(data_dir, batch_size, seq_length)
# 학습데이터에 포함된 모든 단어들을 나타내는 변수인 chars와 chars에 id를 부여해 dict 형태로 만든 vocab을 선언합니다.
chars = data_loader.chars 
vocab = data_loader.vocab
vocab_size = data_loader.vocab_size # 전체 단어개수

# 인풋데이터와 타겟데이터, 배치 사이즈를 입력받기 위한 플레이스홀더를 설정합니다.
input_data = tf.placeholder(tf.int32, shape=[None, None])  # input_data : [batch_size, seq_length])
target_data = tf.placeholder(tf.int32, shape=[None, None]) # target_data : [batch_size, seq_length])
state_batch_size = tf.placeholder(tf.int32, shape=[])      # Training : 50, Sampling : 1

# RNN의 마지막 히든레이어의 출력을 소프트맥스 출력값으로 변환해주기 위한 변수들을 선언합니다.
# hidden_size -> vocab_size
softmax_w = tf.Variable(tf.random_normal(shape=[hidden_size, vocab_size]), dtype=tf.float32)
softmax_b = tf.Variable(tf.random_normal(shape=[vocab_size]), dtype=tf.float32)

# num_hidden_layers만큼 LSTM cell(히든레이어)를 선언합니다.
cells = []
for _ in range(0, num_hidden_layers):
    cell = tf.nn.rnn_cell.BasicLSTMCell(hidden_size)
    cells.append(cell)

# cell을 종합해서 RNN을 정의합니다.
cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)

# 인풋데이터를 변환하기 위한 Embedding Matrix를 선언합니다.
# hidden_size -> vocab_size
embedding = tf.Variable(tf.random_normal(shape=[vocab_size, hidden_size]), dtype=tf.float32)
inputs = tf.nn.embedding_lookup(embedding, input_data)

# 초기 state 값을 0으로 초기화합니다.
initial_state = cell.zero_state(state_batch_size, tf.float32)

# 학습을 위한 tf.nn.dynamic_rnn을 선언합니다.
# outputs : [batch_size, seq_length, hidden_size]
outputs, final_state = tf.nn.dynamic_rnn(cell, inputs, initial_state=initial_state, dtype=tf.float32)
# ouputs을 [batch_size * seq_length, hidden_size]] 형태로 바꿉니다.
output = tf.reshape(outputs, [-1, hidden_size])

# 최종 출력값을 설정합니다.
# logits : [batch_size * seq_length, vocab_size]
logits = tf.matmul(output, softmax_w) + softmax_b
probs = tf.nn.softmax(logits)

# Cross Entropy 손실 함수를 정의합니다. 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=target_data))

# 옵티마이저를 선언하고 옵티마이저에 Gradient Clipping을 적용합니다.
# grad_clip(=5)보다 큰 Gradient를 5로 Clippin합니다.
tvars = tf.trainable_variables()
grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.apply_gradients(zip(grads, tvars))

# 세션을 열고 학습을 진행합니다.
with tf.Session() as sess:
    # 변수들에 초기값을 할당합니다.
    sess.run(tf.global_variables_initializer())
    
    for e in range(num_epochs):
        data_loader.reset_batch_pointer()
        # 초기 상태값을 지정합니다.
        state = sess.run(initial_state, feed_dict={state_batch_size : batch_size})

        for b in range(data_loader.num_batches):
            # x, y 데이터를 불러옵니다.
            x, y = data_loader.next_batch()
            # y에 one_hot 인코딩을 적용합니다. 
            y = tf.one_hot(y, vocab_size)            # y : [batch_size, seq_length, vocab_size]
            y = tf.reshape(y, [-1, vocab_size])       # y : [batch_size * seq_length, vocab_size]
            y = y.eval()

            # feed-dict에 사용할 값들과 LSTM 초기 cell state(feed_dict[c])값과 hidden layer 출력값(feed_dict[h])을 지정합니다.
            feed_dict = {input_data : x, target_data: y, state_batch_size : batch_size}
            for i, (c, h) in enumerate(initial_state):
                feed_dict[c] = state[i].c
                feed_dict[h] = state[i].h

            # 한스텝 학습을 진행합니다.
            _, loss_print, state = sess.run([train_step, loss, final_state], feed_dict=feed_dict)

            print("{}(학습한 배치개수)/{}(학습할 배치개수), 반복(epoch): {}, 손실함수(loss): {:.3f}".format(
                          e * data_loader.num_batches + b,
                          num_epochs * data_loader.num_batches,
                          (e+1), 
                          loss_print))

    print("트레이닝이 끝났습니다!")   
    

    # 샘플링 시작
    print("샘플링을 시작합니다!")
    num_sampling = 4000  # 생성할 글자(Character)의 개수를 지정합니다. 
    prime = u' '         # 시작 글자를 ' '(공백)으로 지정합니다.
    sampling_type = 1    # 샘플링 타입을 설정합니다.
    state = sess.run(cell.zero_state(1, tf.float32)) # RNN의 최초 state값을 0으로 초기화합니다.

    # Random Sampling을 위한 weighted_pick 함수를 정의합니다.
    def weighted_pick(weights):
        t = np.cumsum(weights)
        s = np.sum(weights)
        return(int(np.searchsorted(t, np.random.rand(1)*s)))

    ret = prime       # 샘플링 결과를 리턴받을 ret 변수에 첫번째 글자를 할당합니다.
    char = prime      # Char-RNN의 첫번쨰 인풋을 지정합니다.  
    for n in range(num_sampling):
        x = np.zeros((1, 1))
        x[0, 0] = vocab[char]

        # RNN을 한스텝 실행하고 Softmax 행렬을 리턴으로 받습니다.
        feed_dict = {input_data: x, state_batch_size : 1, initial_state: state}
        [probs_result, state] = sess.run([probs, final_state], feed_dict=feed_dict)         

        # 불필요한 차원을 제거합니다.
        # probs_result : (1,65) -> p : (65)
        p = np.squeeze(probs_result)

        # 샘플링 타입에 따라 3가지 종류로 샘플링 합니다.
        # sampling_type : 0 -> 다음 글자를 예측할때 항상 argmax를 사용
        # sampling_type : 1(defualt) -> 다음 글자를 예측할때 항상 random sampling을 사용
        # sampling_type : 2 -> 다음 글자를 예측할때 이전 글자가 ' '(공백)이면 random sampling, 그렇지 않을 경우 argmax를 사용
        if sampling_type == 0:
            sample = np.argmax(p)
        elif sampling_type == 2:
            if char == ' ':
                sample = weighted_pick(p)
            else:
                sample = np.argmax(p)
        else:
            sample = weighted_pick(p)

        pred = chars[sample]
        ret += pred     # 샘플링 결과에 현재 스텝에서 예측한 글자를 추가합니다. (예를들어 pred=L일 경우, ret = HEL -> HELL)
        char = pred     # 예측한 글자를 다음 RNN의 인풋으로 사용합니다.

    print("샘플링 결과:")
    print(ret)
# Out:
# reading text file
# WARNING:tensorflow:From <ipython-input-13-39ec8aa2b170>:42: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# WARNING:tensorflow:From <ipython-input-13-39ec8aa2b170>:68: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 0(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 5.116
# 1(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.171
# 2(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.896
# 3(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.947
# 4(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.649
# 5(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.565
# 6(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.578
# 7(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.448
# 8(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.304
# 9(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.321
# 10(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.249
# 11(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.222
# 12(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.176
# 13(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.151
# 14(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.163
# 15(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.076
# 16(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.052
# 17(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.046
# 18(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.994
# 19(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.960
# 20(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.955
# 21(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.955
# 22(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.913
# 23(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.890
# 24(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.848
# 25(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.834
# 26(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.769
# 27(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.779
# 28(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.715
# 29(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.718
# 30(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.722
# 31(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.752
# 32(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.625
# 33(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.634
# 34(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.626
# 35(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.611
# 36(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.670
# 37(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.606
# 38(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.598
# 39(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.580
# 40(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.598
# 41(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.536
# 42(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.498
# 43(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.445
# 44(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.525
# 45(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.474
# 46(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.423
# 47(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.460
# 48(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.449
# 49(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.410
# 50(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.435
# 51(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.386
# 52(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.388
# 53(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.420
# 54(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.390
# 55(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.371
# 56(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.318
# 57(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.335
# 58(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.323
# 59(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.289
# 60(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.360
# 61(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.380
# 62(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.303
# 63(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.365
# 64(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.305
# 65(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.291
# 66(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.285
# 67(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.277
# 68(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.311
# 69(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.278
# 70(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.233
# 71(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.265
# 72(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.253
# 73(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.219
# 74(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.205
# 75(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.200
# 76(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.219
# 77(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.237
# 78(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.219
# 79(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.193
# 80(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.238
# 81(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.133
# 82(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.167
# 83(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.171
# 84(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.203
# 85(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.161
# 86(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.128
# 87(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.098
# 88(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.222
# 89(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.106
# 90(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.102
# 91(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.084
# 92(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.112
# 93(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.089
# 94(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.159
# 95(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.139
# 96(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.154
# 97(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.090
# 98(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.075
# 99(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.144
# 100(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.089
# 101(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.075
# 102(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.109
# 103(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.081
# 104(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.066
# 105(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.076
# 106(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.043
# 107(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.070
# 108(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.089
# 109(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.022
# 110(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.988
# 111(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.066
# 112(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.051
# 113(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.056
# 114(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.082
# 115(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.077
# 116(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.041
# 117(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.070
# 118(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.014
# 119(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.941
# 120(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.024
# 121(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.014
# 122(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.978
# 123(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.984
# 124(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.017
# 125(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.062
# 126(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.979
# 127(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.011
# 128(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.058
# 129(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.958
# 130(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.940
# 131(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.999
# 132(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.032
# 133(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.971
# 134(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.958
# 135(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.016
# 136(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.006
# 137(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.024
# 138(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.026
# 139(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.052
# 140(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.033
# 141(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.006
# 142(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.937
# 143(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.959
# 144(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.976
# 145(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.980
# 146(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.935
# 147(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.925
# 148(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.984
# 149(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.976
# 150(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.920
# 151(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.977
# 152(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.945
# 153(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.955
# 154(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.954
# 155(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 156(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.908
# 157(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 158(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 159(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.937
# 160(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.898
# 161(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.025
# 162(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.957
# 163(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.925
# 164(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.971
# 165(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.963
# 166(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.908
# 167(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.856
# 168(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.947
# 169(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.959
# 170(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.947
# 171(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.970
# 172(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.918
# 173(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.897
# 174(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.951
# 175(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.960
# 176(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.932
# 177(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.879
# 178(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.857
# 179(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.861
# 180(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.878
# 181(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.914
# 182(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.904
# 183(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.898
# 184(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.803
# 185(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.867
# 186(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.887
# 187(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.917
# 188(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.897
# 189(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.811
# 190(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.886
# 191(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.797
# 192(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.867
# 193(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.844
# 194(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.890
# 195(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 196(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.835
# 197(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.876
# 198(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.930
# 199(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.895
# 200(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.894
# 201(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.858
# 202(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.896
# 203(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.850
# 204(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.877
# 205(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 206(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.891
# 207(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 208(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 209(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.868
# 210(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 211(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 212(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.873
# 213(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.882
# 214(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.787
# 215(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.831
# 216(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.869
# 217(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.849
# 218(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.812
# 219(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.836
# 220(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 221(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.900
# 222(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.856
# 223(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.842
# 224(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.819
# 225(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.817
# 226(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.900
# 227(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 228(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.878
# 229(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.848
# 230(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.871
# 231(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.840
# 232(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.816
# 233(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.869
# 234(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.846
# 235(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 236(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.834
# 237(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 238(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.802
# 239(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.834
# 240(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.829
# 241(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.777
# 242(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.799
# 243(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.858
# 244(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 245(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 246(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.819
# 247(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.813
# 248(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.851
# 249(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.750
# 250(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.840
# 251(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.716
# 252(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.827
# 253(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.782
# 254(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.801
# 255(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.787
# 256(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.781
# 257(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.768
# 258(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.818
# 259(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.770
# 260(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 261(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.750
# 262(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.756
# 263(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 264(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 265(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.829
# 266(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.858
# 267(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.794
# 268(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.785
# 269(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.774
# 270(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.783
# 271(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.831
# 272(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.754
# 273(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 274(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 275(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.816
# 276(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.782
# 277(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.808
# 278(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 279(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.828
# 280(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.765
# 281(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.836
# 282(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.741
# 283(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 284(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.772
# 285(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.748
# 286(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.729
# 287(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.804
# 288(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 289(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.725
# 290(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.777
# 291(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.787
# 292(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 293(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.773
# 294(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.811
# 295(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 296(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 297(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 298(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 299(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.711
# 300(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 301(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.768
# 302(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.692
# 303(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.659
# 304(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.789
# 305(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.778
# 306(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 307(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.778
# 308(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.799
# 309(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.770
# 310(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.737
# 311(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.815
# 312(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.809
# 313(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.805
# 314(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 315(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 316(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 317(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.762
# 318(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 319(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 320(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.707
# 321(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 322(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 323(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 324(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.723
# 325(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.712
# 326(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.712
# 327(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 328(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.760
# 329(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.688
# 330(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 331(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.753
# 332(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.696
# 333(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.617
# 334(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.709
# 335(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.702
# 336(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 337(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.727
# 338(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.806
# 339(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.669
# 340(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.751
# 341(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.639
# 342(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.717
# 343(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.715
# 344(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.640
# 345(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.725
# 346(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 347(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.759
# 348(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.684
# 349(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 350(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 351(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.709
# 352(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.648
# 353(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.639
# 354(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.634
# 355(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.716
# 356(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 357(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.743
# 358(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.667
# 359(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.685
# 360(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.738
# 361(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 362(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 363(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.728
# 364(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.716
# 365(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 366(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.688
# 367(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 368(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 369(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 370(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 371(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.679
# 372(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 373(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.705
# 374(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.713
# 375(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 376(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 377(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 378(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 379(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 380(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 381(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 382(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.759
# 383(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 384(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 385(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.755
# 386(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.705
# 387(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 388(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 389(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.644
# 390(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.672
# 391(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.709
# 392(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.689
# 393(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 394(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.650
# 395(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.703
# 396(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.641
# 397(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.625
# 398(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 399(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.656
# 400(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.718
# 401(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.699
# 402(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 403(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.729
# 404(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 405(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.705
# 406(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 407(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.663
# 408(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.741
# 409(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 410(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.715
# 411(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.645
# 412(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.696
# 413(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.646
# 414(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.663
# 415(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.679
# 416(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.648
# 417(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.636
# 418(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 419(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 420(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 421(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.679
# 422(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 423(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.731
# 424(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.687
# 425(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.668
# 426(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 427(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.670
# 428(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.664
# 429(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.709
# 430(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.636
# 431(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.756
# 432(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.664
# 433(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.688
# 434(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.646
# 435(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.656
# 436(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 437(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 438(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.744
# 439(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.625
# 440(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.689
# 441(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.604
# 442(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.631
# 443(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 444(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.651
# 445(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.643
# 446(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.804
# 447(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.659
# 448(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.639
# 449(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.640
# 450(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.723
# 451(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.680
# 452(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.680
# 453(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.697
# 454(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.619
# 455(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.552
# 456(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.699
# 457(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 458(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.669
# 459(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.625
# 460(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 461(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 462(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.694
# 463(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 464(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.613
# 465(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.635
# 466(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 467(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 468(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 469(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 470(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 471(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 472(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 473(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 474(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.663
# 475(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.640
# 476(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.646
# 477(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.665
# 478(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 479(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 480(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.671
# 481(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.608
# 482(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.745
# 483(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.710
# 484(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.648
# 485(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.671
# 486(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.684
# 487(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.688
# 488(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.608
# 489(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 490(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.686
# 491(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.646
# 492(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 493(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.592
# 494(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.623
# 495(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 496(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 497(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 498(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 499(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 500(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 501(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 502(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 503(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.631
# 504(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 505(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.594
# 506(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.666
# 507(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.635
# 508(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.618
# 509(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.666
# 510(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.591
# 511(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.639
# 512(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 513(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.662
# 514(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.664
# 515(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.643
# 516(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.630
# 517(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 518(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.650
# 519(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 520(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 521(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.637
# 522(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.646
# 523(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.625
# 524(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 525(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.651
# 526(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 527(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 528(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 529(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 530(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 531(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.641
# 532(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 533(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 534(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.672
# 535(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 536(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 537(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 538(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 539(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 540(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.606
# 541(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.659
# 542(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 543(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.642
# 544(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 545(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.653
# 546(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.552
# 547(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 548(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.641
# 549(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.570
# 550(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 551(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 552(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 553(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 554(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 555(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 556(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 557(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 558(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 559(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 560(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.599
# 561(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 562(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.602
# 563(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.642
# 564(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 565(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 566(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.614
# 567(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 568(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 569(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 570(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.639
# 571(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.661
# 572(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 573(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 574(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.656
# 575(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 576(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 577(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 578(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.640
# 579(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.594
# 580(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 581(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.627
# 582(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.630
# 583(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.664
# 584(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.653
# 585(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.633
# 586(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.624
# 587(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 588(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.542
# 589(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.561
# 590(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.566
# 591(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 592(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 593(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 594(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.594
# 595(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 596(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 597(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.619
# 598(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 599(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 600(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 601(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 602(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 603(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 604(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 605(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 606(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 607(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.716
# 608(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 609(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 610(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.639
# 611(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 612(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 613(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 614(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.613
# 615(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.647
# 616(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 617(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 618(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 619(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.566
# 620(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.623
# 621(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.622
# 622(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.601
# 623(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 624(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 625(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 626(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 627(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 628(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.602
# 629(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.591
# 630(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 631(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 632(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.601
# 633(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 634(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 635(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 636(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 637(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.491
# 638(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 639(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.593
# 640(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.611
# 641(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 642(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.534
# 643(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 644(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.592
# 645(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.619
# 646(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.651
# 647(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 648(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 649(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 650(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 651(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 652(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.591
# 653(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 654(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.653
# 655(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 656(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 657(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 658(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 659(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 660(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 661(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 662(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 663(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 664(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 665(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.565
# 666(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.570
# 667(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 668(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.599
# 669(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 670(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 671(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 672(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.622
# 673(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.565
# 674(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 675(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 676(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 677(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 678(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 679(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 680(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.601
# 681(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 682(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 683(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 684(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 685(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 686(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 687(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 688(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 689(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.583
# 690(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 691(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 692(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 693(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 694(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 695(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 696(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.602
# 697(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 698(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.599
# 699(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 700(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.564
# 701(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 702(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 703(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.542
# 704(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.552
# 705(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 706(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 707(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.526
# 708(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 709(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 710(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 711(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 712(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 713(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.564
# 714(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 715(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 716(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 717(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 718(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 719(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 720(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 721(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.602
# 722(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.570
# 723(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 724(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 725(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 726(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 727(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 728(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 729(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.523
# 730(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 731(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 732(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 733(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 734(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 735(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.560
# 736(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 737(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.527
# 738(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 739(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 740(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 741(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 742(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.576
# 743(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.511
# 744(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 745(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 746(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.491
# 747(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 748(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.497
# 749(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.484
# 750(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.567
# 751(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.570
# 752(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.493
# 753(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 754(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.585
# 755(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 756(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.526
# 757(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 758(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 759(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.614
# 760(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.507
# 761(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 762(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 763(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 764(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 765(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.466
# 766(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.489
# 767(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 768(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.525
# 769(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 770(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.533
# 771(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.525
# 772(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 773(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.511
# 774(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 775(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.500
# 776(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.493
# 777(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 778(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.495
# 779(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.430
# 780(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 781(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.521
# 782(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 783(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 784(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.621
# 785(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 786(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 787(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.469
# 788(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 789(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 790(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.460
# 791(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 792(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.515
# 793(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 794(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 795(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.645
# 796(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 797(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 798(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.472
# 799(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.497
# 800(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.470
# 801(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 802(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 803(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 804(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 805(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 806(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.564
# 807(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.506
# 808(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 809(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 810(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 811(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.499
# 812(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 813(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 814(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 815(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.495
# 816(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 817(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.507
# 818(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 819(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 820(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.543
# 821(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 822(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.538
# 823(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.478
# 824(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 825(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.492
# 826(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 827(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 828(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 829(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 830(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 831(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 832(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 833(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 834(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 835(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.470
# 836(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 837(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 838(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 839(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.565
# 840(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 841(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 842(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.485
# 843(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.460
# 844(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 845(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 846(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 847(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 848(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 849(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 850(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 851(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.543
# 852(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 853(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 854(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 855(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 856(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 857(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 858(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 859(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 860(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.507
# 861(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 862(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.506
# 863(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 864(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.503
# 865(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.566
# 866(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.534
# 867(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 868(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.578
# 869(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 870(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 871(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.510
# 872(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 873(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.521
# 874(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.497
# 875(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 876(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 877(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.622
# 878(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.498
# 879(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 880(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.509
# 881(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 882(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 883(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 884(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.622
# 885(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.500
# 886(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.552
# 887(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.456
# 888(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 889(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.476
# 890(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.507
# 891(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.497
# 트레이닝이 끝났습니다!
# 샘플링을 시작합니다!
# 샘플링 결과:
#  Padvain:
# O, which is is one armage:
# Pleavent need kes is not beseent rambing.
# 'God speech me the drue other cannou treatue stander
# For have to givenement prence,
# I know I feasount under massire,
# No lives be Richard's shall'd Wrinkle plaint ain,
# I'll desside to Mancase pain'd poise in act!
#
# WARWICK:
# Whose sent the witre hine. Beady:
# I fight one with a care, very is sint
# Their canst on hor myself
# That I velder with your grace you jest,
# xind with kill, but in the house body.
#
# LUCIO:
# The son Richard; whose me here rate provins
# Whence, honour's gaagar,
# To thank him.
#
# CoPUE:
# What, nor Rugnawree, Warwick she the stildons offer?
#
# CLIFFORD:
# 'My most and, I seadys pinusincat!
#
# BENVOLIO:
#
# Third sut this pisticians; shows in son fair'st thee.
#
# BENVOLIO:
# And warn this this bance will be--hand,
# To king didst thou say, I speak your garied,
# Thy wack fall'd in my come.
#
# BIONDELLO:
#
# SOFIZALD:
#
# First Mercime:
# And here will provide of plaint, good may dects? and play
# So Romeo's; for only uncle stadience,
# To despind is it life. Shall weak me she crack.
#
# Lord:
# I'll thee rage out the chimised, calery go give stirs,
# And frace, as imprace wife, a stant of her
# volucius it name with his master,
# That hands abord and thy die bold,
# Latenisan is name homes valianding on.
#
# GONZALO:
# Nor everny is thee as: I signigh in the Carble
# Bwid rail'd indie thy trother's pentry,
# And where dend it wear kings with their bogediden so stitlesent
# I may you can set you in the pains accurage
# Against alate, trong of you know roved,
# wold die cural he scrail or sweeign'd time.
#
# Lest:
# Game, more fear, God side, mide her hand approwan
# Walk! she's me Richard, I'll flates the warlard
# To-horse the jearse up thee of by thou out frop on a vaic to
# She is be viguard of a than mine;
# Tend yet voices body at heave?
#
# Allo:
# To your ravenes father mean in xoget's frience:
# First what rebaling tranceles a renage tayrave:
# Somer'd accuse this ball. Diral untck him. She hate
# The love-pine: lady him?
#
# ViLdosa their good for -nice, my prince,
# Which soul! downly to have but his son? Click you,
# O him: I will be I swear speak the.
#
# LEONTES:
# Host known
# Unpise him, our have pressed slippts,
# Who, for what have it is dote your some undery but
# Ant for yet news is make a duke of mean.
#
# POLoXXEE:
# Sir, may thou curap: married if of't, ni?
#
# POMPEY:
# If never todes the bide cour father.
#
# YORK:
# And and my lidge, so which pal this dare with dead!
# Looks welcome.
#
# YORK:
# I may let remone Paulis, man's lies,
# To stird, in a Mercut to make king,
# With squry offoreterous spirite you reeming.
#
# Pervant:
# Within, in to ride that with me by Richard's against;
# First rest to for God metiness hear, enjoy. Tolk's dray,
# The is-and make sir; I raw af
# Bast! Unon may foe thy laught.
#
# POTPEY:
# God, have come. they in this and thy halife
# Dote may is in maistrike daming inster?
#
# Second Hirried! he will not.
#
# PRINCE:
# Peter Captiliag: swell,
# I can put breave men me be my wayly sway,
# How his hand with yessic in me part you,
# Or heice: what I sucreding is the turn see my tongarn,
# Nosely, Aleir is sovering to is.
#
# Rlead:
# Aadake, I mine amelains you pleases,
# With saint eyes WorE-For Herery,
# With the agoverary Would sex sit.
#
# ANIELLO:
# He die acques alonman, me lifdly hurd hi? 3
# Which Boubbround, no preses of meeliand wisping royate.
#
# PETER:
# Hereit of my helage in she skillest county.
#
# First Lord:
# Soman, what begin barden mourreadastesgains,
# It you know.
#
# POLIXENES:
# Along boot leave then daughter-to spied.
#
# POLIXENES:
# Por silent sign may that all fiely!
# I come of other, too!
#
# APULIE:
# Plantent, ear ,and'st the sword Sound are daugher?
# No, body with it, will the fair out I am by the way.
#
# Plord:
# Dossing at sleet again, our friends?
#
# Third Servong the Migniora! Hell him? See me acker
# If you slander'd. Duke noT
# Ab pleasoner is his joy: I.
#
# KING RICHARDI II:
# Clity me:
# Master owe percument him thy fair some, me,
# You may brac'me. sic mine Londen, gessiance,
# To are what I have not but men eir,
# It down the carent, now doroply lord; hark you wousin inspeage.

# %%
tf.reset_default_graph()
data_dir = 'Documents/My/data/linux'
batch_size = 50 # Training : 50, Sampling : 1
seq_length = 50 # Training : 50, Sampling : 1
hidden_size = 128   # 히든 레이어의 노드 개수
learning_rate = 0.002
num_epochs = 2
num_hidden_layers = 2
grad_clip = 5   # Gradient Clipping에 사용할 임계값

# TextLoader를 이용해서 데이터를 불러옵니다.
data_loader = TextLoader(data_dir, batch_size, seq_length)
# 학습데이터에 포함된 모든 단어들을 나타내는 변수인 chars와 chars에 id를 부여해 dict 형태로 만든 vocab을 선언합니다.
chars = data_loader.chars 
vocab = data_loader.vocab
vocab_size = data_loader.vocab_size # 전체 단어개수

# 인풋데이터와 타겟데이터, 배치 사이즈를 입력받기 위한 플레이스홀더를 설정합니다.
input_data = tf.placeholder(tf.int32, shape=[None, None])  # input_data : [batch_size, seq_length])
target_data = tf.placeholder(tf.int32, shape=[None, None]) # target_data : [batch_size, seq_length])
state_batch_size = tf.placeholder(tf.int32, shape=[])      # Training : 50, Sampling : 1

# RNN의 마지막 히든레이어의 출력을 소프트맥스 출력값으로 변환해주기 위한 변수들을 선언합니다.
# hidden_size -> vocab_size
softmax_w = tf.Variable(tf.random_normal(shape=[hidden_size, vocab_size]), dtype=tf.float32)
softmax_b = tf.Variable(tf.random_normal(shape=[vocab_size]), dtype=tf.float32)

# num_hidden_layers만큼 LSTM cell(히든레이어)를 선언합니다.
cells = []
for _ in range(0, num_hidden_layers):
    cell = tf.nn.rnn_cell.BasicLSTMCell(hidden_size)
    cells.append(cell)

# cell을 종합해서 RNN을 정의합니다.
cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)

# 인풋데이터를 변환하기 위한 Embedding Matrix를 선언합니다.
# hidden_size -> vocab_size
embedding = tf.Variable(tf.random_normal(shape=[vocab_size, hidden_size]), dtype=tf.float32)
inputs = tf.nn.embedding_lookup(embedding, input_data)

# 초기 state 값을 0으로 초기화합니다.
initial_state = cell.zero_state(state_batch_size, tf.float32)

# 학습을 위한 tf.nn.dynamic_rnn을 선언합니다.
# outputs : [batch_size, seq_length, hidden_size]
outputs, final_state = tf.nn.dynamic_rnn(cell, inputs, initial_state=initial_state, dtype=tf.float32)
# ouputs을 [batch_size * seq_length, hidden_size]] 형태로 바꿉니다.
output = tf.reshape(outputs, [-1, hidden_size])

# 최종 출력값을 설정합니다.
# logits : [batch_size * seq_length, vocab_size]
logits = tf.matmul(output, softmax_w) + softmax_b
probs = tf.nn.softmax(logits)

# Cross Entropy 손실 함수를 정의합니다. 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=target_data))

# 옵티마이저를 선언하고 옵티마이저에 Gradient Clipping을 적용합니다.
# grad_clip(=5)보다 큰 Gradient를 5로 Clippin합니다.
tvars = tf.trainable_variables()
grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.apply_gradients(zip(grads, tvars))

# 세션을 열고 학습을 진행합니다.
with tf.Session() as sess:
    # 변수들에 초기값을 할당합니다.
    sess.run(tf.global_variables_initializer())
    
    for e in range(num_epochs):
        data_loader.reset_batch_pointer()
        # 초기 상태값을 지정합니다.
        state = sess.run(initial_state, feed_dict={state_batch_size : batch_size})

        for b in range(data_loader.num_batches):
            # x, y 데이터를 불러옵니다.
            x, y = data_loader.next_batch()
            # y에 one_hot 인코딩을 적용합니다. 
            y = tf.one_hot(y, vocab_size)            # y : [batch_size, seq_length, vocab_size]
            y = tf.reshape(y, [-1, vocab_size])       # y : [batch_size * seq_length, vocab_size]
            y = y.eval()

            # feed-dict에 사용할 값들과 LSTM 초기 cell state(feed_dict[c])값과 hidden layer 출력값(feed_dict[h])을 지정합니다.
            feed_dict = {input_data : x, target_data: y, state_batch_size : batch_size}
            for i, (c, h) in enumerate(initial_state):
                feed_dict[c] = state[i].c
                feed_dict[h] = state[i].h

            # 한스텝 학습을 진행합니다.
            _, loss_print, state = sess.run([train_step, loss, final_state], feed_dict=feed_dict)

            print("{}(학습한 배치개수)/{}(학습할 배치개수), 반복(epoch): {}, 손실함수(loss): {:.3f}".format(
                          e * data_loader.num_batches + b,
                          num_epochs * data_loader.num_batches,
                          (e+1), 
                          loss_print))

    print("트레이닝이 끝났습니다!")   
    

    # 샘플링 시작
    print("샘플링을 시작합니다!")
    num_sampling = 4000  # 생성할 글자(Character)의 개수를 지정합니다. 
    prime = u' '         # 시작 글자를 ' '(공백)으로 지정합니다.
    sampling_type = 1    # 샘플링 타입을 설정합니다.
    state = sess.run(cell.zero_state(1, tf.float32)) # RNN의 최초 state값을 0으로 초기화합니다.

    # Random Sampling을 위한 weighted_pick 함수를 정의합니다.
    def weighted_pick(weights):
        t = np.cumsum(weights)
        s = np.sum(weights)
        return(int(np.searchsorted(t, np.random.rand(1)*s)))

    ret = prime       # 샘플링 결과를 리턴받을 ret 변수에 첫번째 글자를 할당합니다.
    char = prime      # Char-RNN의 첫번쨰 인풋을 지정합니다.  
    for n in range(num_sampling):
        x = np.zeros((1, 1))
        x[0, 0] = vocab[char]

        # RNN을 한스텝 실행하고 Softmax 행렬을 리턴으로 받습니다.
        feed_dict = {input_data: x, state_batch_size : 1, initial_state: state}
        [probs_result, state] = sess.run([probs, final_state], feed_dict=feed_dict)         

        # 불필요한 차원을 제거합니다.
        # probs_result : (1,65) -> p : (65)
        p = np.squeeze(probs_result)

        # 샘플링 타입에 따라 3가지 종류로 샘플링 합니다.
        # sampling_type : 0 -> 다음 글자를 예측할때 항상 argmax를 사용
        # sampling_type : 1(defualt) -> 다음 글자를 예측할때 항상 random sampling을 사용
        # sampling_type : 2 -> 다음 글자를 예측할때 이전 글자가 ' '(공백)이면 random sampling, 그렇지 않을 경우 argmax를 사용
        if sampling_type == 0:
            sample = np.argmax(p)
        elif sampling_type == 2:
            if char == ' ':
                sample = weighted_pick(p)
            else:
                sample = np.argmax(p)
        else:
            sample = weighted_pick(p)

        pred = chars[sample]
        ret += pred     # 샘플링 결과에 현재 스텝에서 예측한 글자를 추가합니다. (예를들어 pred=L일 경우, ret = HEL -> HELL)
        char = pred     # 예측한 글자를 다음 RNN의 인풋으로 사용합니다.

    print("샘플링 결과:")
    print(ret)
# Out:
# loading preprocessed files
# 0(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.925
# 1(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.398
# 2(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.073
# 3(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.875
# 4(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.784
# 5(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.733
# 6(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.523
# 7(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.484
# 8(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.471
# 9(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.430
# 10(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.401
# 11(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.425
# 12(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.404
# 13(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.424
# 14(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.341
# 15(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.260
# 16(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.302
# 17(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.276
# 18(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.293
# 19(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.156
# 20(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.186
# 21(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.175
# 22(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.137
# 23(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.120
# 24(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.065
# 25(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.037
# 26(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.020
# 27(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.068
# 28(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.130
# 29(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.031
# 30(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.093
# 31(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.016
# 32(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.001
# 33(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.981
# 34(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.899
# 35(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.868
# 36(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.910
# 37(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.773
# 38(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.756
# 39(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.848
# 40(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.711
# 41(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.674
# 42(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.613
# 43(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.573
# 44(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.664
# 45(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.627
# 46(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.628
# 47(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.638
# 48(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.619
# 49(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.635
# 50(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.588
# 51(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.613
# 52(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.541
# 53(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.628
# 54(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.610
# 55(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.493
# 56(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.533
# 57(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.457
# 58(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.517
# 59(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.551
# 60(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.490
# 61(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.491
# 62(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.447
# 63(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.496
# 64(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.443
# 65(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.448
# 66(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.454
# 67(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.406
# 68(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.420
# 69(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.438
# 70(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.354
# 71(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.393
# 72(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.323
# 73(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.327
# 74(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.367
# 75(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.421
# 76(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.366
# 77(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.299
# 78(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.448
# 79(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.301
# 80(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.323
# 81(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.289
# 82(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.227
# 83(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.270
# 84(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.298
# 85(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.316
# 86(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.273
# 87(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.257
# 88(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.161
# 89(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.222
# 90(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.230
# 91(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.202
# 92(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.234
# 93(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.174
# 94(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.199
# 95(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.257
# 96(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.150
# 97(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.214
# 98(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.163
# 99(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.202
# 100(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.269
# 101(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.205
# 102(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.173
# 103(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.041
# 104(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.141
# 105(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.089
# 106(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.054
# 107(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.004
# 108(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.066
# 109(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.045
# 110(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.075
# 111(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.071
# 112(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.005
# 113(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.997
# 114(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.012
# 115(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.997
# 116(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.051
# 117(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.019
# 118(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.967
# 119(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.031
# 120(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.061
# 121(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.017
# 122(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.201
# 123(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.024
# 124(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.012
# 125(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.990
# 126(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.082
# 127(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.074
# 128(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.026
# 129(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.964
# 130(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.922
# 131(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.923
# 132(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.874
# 133(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 134(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.935
# 135(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.905
# 136(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.934
# 137(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.939
# 138(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.001
# 139(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.987
# 140(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.975
# 141(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.998
# 142(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.915
# 143(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.933
# 144(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.950
# 145(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.944
# 146(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.917
# 147(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.939
# 148(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.983
# 149(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.880
# 150(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.979
# 151(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.903
# 152(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.875
# 153(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.844
# 154(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.808
# 155(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.904
# 156(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.874
# 157(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.881
# 158(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.859
# 159(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.917
# 160(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.018
# 161(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 162(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.899
# 163(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.849
# 164(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 165(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.978
# 166(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.976
# 167(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.911
# 168(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.899
# 169(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.846
# 170(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.839
# 171(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.942
# 172(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.876
# 173(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.828
# 174(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.873
# 175(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 176(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.832
# 177(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.823
# 178(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.802
# 179(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.821
# 180(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.819
# 181(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.851
# 182(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.812
# 183(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.846
# 184(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.811
# 185(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.756
# 186(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.826
# 187(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.759
# 188(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.806
# 189(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.781
# 190(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.711
# 191(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.743
# 192(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.813
# 193(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.869
# 194(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.831
# 195(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.738
# 196(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.805
# 197(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 198(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.835
# 199(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.770
# 200(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.650
# 201(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.828
# 202(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.692
# 203(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.793
# 204(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.714
# 205(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.753
# 206(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 207(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.744
# 208(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.745
# 209(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 210(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 211(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.741
# 212(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.725
# 213(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.702
# 214(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.749
# 215(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.764
# 216(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.748
# 217(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.767
# 218(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 219(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.785
# 220(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 221(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 222(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.669
# 223(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.788
# 224(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.790
# 225(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.847
# 226(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.791
# 227(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 228(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 229(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 230(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 231(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 232(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.775
# 233(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 234(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 235(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 236(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.733
# 237(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.661
# 238(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.635
# 239(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.740
# 240(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.684
# 241(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 242(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 243(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.661
# 244(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.826
# 245(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 246(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.714
# 247(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 248(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 249(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.659
# 250(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.792
# 251(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.821
# 252(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.664
# 253(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 254(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.713
# 255(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.701
# 256(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.762
# 257(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.714
# 258(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.592
# 259(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.641
# 260(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 261(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.718
# 262(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.795
# 263(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.797
# 264(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.834
# 265(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.769
# 266(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 267(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.609
# 268(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.762
# 269(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.758
# 270(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.668
# 271(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.687
# 272(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 273(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.597
# 274(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.808
# 275(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.617
# 276(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.735
# 277(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 278(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.625
# 279(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.722
# 280(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 281(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.682
# 282(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.666
# 283(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 284(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.645
# 285(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 286(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.725
# 287(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.635
# 288(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.604
# 289(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.682
# 290(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.656
# 291(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.672
# 292(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 293(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 294(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 295(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 296(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.584
# 297(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.574
# 298(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 299(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.613
# 300(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.658
# 301(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.692
# 302(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.735
# 303(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 304(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.595
# 305(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.857
# 306(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.679
# 307(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.582
# 308(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.652
# 309(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.632
# 310(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 311(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 312(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.631
# 313(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.633
# 314(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.621
# 315(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 316(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.649
# 317(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.649
# 318(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 319(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.555
# 320(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 321(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 322(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.585
# 323(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.649
# 324(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.567
# 325(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 326(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.647
# 327(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.622
# 328(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.625
# 329(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.592
# 330(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.594
# 331(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.497
# 332(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.572
# 333(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 334(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.615
# 335(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.584
# 336(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.470
# 337(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.523
# 338(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.448
# 339(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.449
# 340(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.494
# 341(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.542
# 342(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.523
# 343(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.466
# 344(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.480
# 345(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.552
# 346(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.651
# 347(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 348(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 349(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.648
# 350(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.703
# 351(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.705
# 352(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 353(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.672
# 354(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 355(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.566
# 356(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.632
# 357(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.644
# 358(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.641
# 359(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 360(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.633
# 361(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.656
# 362(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.522
# 363(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.520
# 364(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.589
# 365(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.535
# 366(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.573
# 367(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.529
# 368(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.643
# 369(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.466
# 370(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.596
# 371(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 372(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.611
# 373(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.539
# 374(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.517
# 375(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.642
# 376(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.572
# 377(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.605
# 378(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.547
# 379(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.570
# 380(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.643
# 381(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 382(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 383(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.658
# 384(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 385(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.502
# 386(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.591
# 387(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.597
# 388(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 389(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.590
# 390(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.484
# 391(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.550
# 392(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 393(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.544
# 394(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.627
# 395(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.665
# 396(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.701
# 397(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.637
# 398(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.703
# 399(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 400(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.633
# 401(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.606
# 402(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.519
# 403(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.581
# 404(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.623
# 405(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.526
# 406(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 407(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.766
# 408(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.722
# 409(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.707
# 410(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.636
# 411(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.684
# 412(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.527
# 413(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.449
# 414(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.479
# 415(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.440
# 416(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.470
# 417(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.488
# 418(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.529
# 419(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.478
# 420(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.493
# 421(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.419
# 422(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.551
# 423(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.608
# 424(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.491
# 425(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.587
# 426(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 427(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.571
# 428(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.520
# 429(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.537
# 430(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.530
# 431(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.533
# 432(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.556
# 433(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.559
# 434(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.659
# 435(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.524
# 436(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.505
# 437(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.542
# 438(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.556
# 439(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 440(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.608
# 441(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 442(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.496
# 443(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.550
# 444(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.604
# 445(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.567
# 446(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.522
# 447(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.437
# 448(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.548
# 449(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.580
# 450(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.622
# 451(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.617
# 452(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.621
# 453(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.583
# 454(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.518
# 455(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.551
# 456(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.579
# 457(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.581
# 458(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.511
# 459(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.571
# 460(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.568
# 461(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.567
# 462(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.526
# 463(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.503
# 464(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.542
# 465(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.580
# 466(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.545
# 467(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.551
# 468(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.480
# 469(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.503
# 470(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.482
# 471(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.446
# 472(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.409
# 473(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.514
# 474(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.507
# 475(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.509
# 476(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.501
# 477(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.511
# 478(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.553
# 479(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.507
# 480(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.528
# 481(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.438
# 482(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.485
# 483(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.467
# 484(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.455
# 485(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.460
# 486(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.444
# 487(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.527
# 488(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.509
# 489(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.473
# 490(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.517
# 491(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.528
# 492(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.520
# 493(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.494
# 494(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.417
# 495(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.534
# 496(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.477
# 497(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.457
# 498(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.455
# 499(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.436
# 500(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.412
# 501(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 502(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.449
# 503(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.416
# 504(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 505(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.490
# 506(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.517
# 507(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.477
# 508(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.466
# 509(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 510(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 511(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.519
# 512(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 513(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.471
# 514(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 515(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 516(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.435
# 517(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.465
# 518(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.523
# 519(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 520(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 521(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.460
# 522(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.426
# 523(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 524(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.482
# 525(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.413
# 526(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.400
# 527(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 528(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.458
# 529(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 530(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 531(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 532(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.426
# 533(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.457
# 534(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 535(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 536(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 537(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 538(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.476
# 539(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.430
# 540(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.521
# 541(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.468
# 542(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.408
# 543(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.385
# 544(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 545(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 546(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.420
# 547(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.434
# 548(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 549(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.491
# 550(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 551(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.426
# 552(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.454
# 553(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.411
# 554(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 555(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 556(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.478
# 557(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.515
# 558(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.451
# 559(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.427
# 560(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 561(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.542
# 562(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.490
# 563(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.456
# 564(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 565(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 566(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.500
# 567(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 568(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 569(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 570(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 571(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.457
# 572(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.464
# 573(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 574(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.423
# 575(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.422
# 576(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 577(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.471
# 578(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.436
# 579(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.523
# 580(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.457
# 581(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.423
# 582(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.403
# 583(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 584(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 585(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.442
# 586(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 587(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.464
# 588(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.471
# 589(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.386
# 590(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 591(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.419
# 592(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 593(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.404
# 594(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.430
# 595(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.450
# 596(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.463
# 597(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 598(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.487
# 599(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 600(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.430
# 601(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 602(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.464
# 603(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.407
# 604(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.284
# 605(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.368
# 606(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.336
# 607(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.383
# 608(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 609(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 610(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 611(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 612(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.388
# 613(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.326
# 614(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 615(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.303
# 616(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 617(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.374
# 618(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.336
# 619(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 620(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.411
# 621(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.357
# 622(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.396
# 623(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.487
# 624(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 625(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 626(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.337
# 627(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.442
# 628(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.454
# 629(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 630(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.348
# 631(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.299
# 632(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.344
# 633(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 634(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 635(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 636(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.368
# 637(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 638(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.383
# 639(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.443
# 640(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.495
# 641(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.424
# 642(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.439
# 643(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 644(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.425
# 645(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.386
# 646(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.438
# 647(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.421
# 648(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.396
# 649(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.438
# 650(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.374
# 651(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.452
# 652(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.394
# 653(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.307
# 654(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 655(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.302
# 656(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.388
# 657(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 658(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 659(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 660(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.384
# 661(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.483
# 662(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 663(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.392
# 664(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 665(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 666(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.473
# 667(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.507
# 668(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.437
# 669(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.402
# 670(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 671(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 672(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.474
# 673(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.397
# 674(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.383
# 675(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 676(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 677(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 678(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 679(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 680(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 681(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.346
# 682(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 683(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 684(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 685(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.336
# 686(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.306
# 687(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.369
# 688(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.287
# 689(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.353
# 690(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 691(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.249
# 692(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 693(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 694(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.411
# 695(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.415
# 696(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.317
# 697(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.398
# 698(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.415
# 699(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.403
# 700(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 701(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 702(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.394
# 703(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.269
# 704(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.402
# 705(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.309
# 706(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.339
# 707(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.371
# 708(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.355
# 709(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 710(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 711(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 712(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.337
# 713(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 714(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.311
# 715(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 716(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.376
# 717(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 718(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.375
# 719(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 720(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 721(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.310
# 722(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.447
# 723(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.297
# 724(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.362
# 725(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 726(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.429
# 727(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.378
# 728(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 729(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.282
# 730(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.268
# 731(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 732(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 733(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 734(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.311
# 735(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.316
# 736(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 737(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 738(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.270
# 739(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.249
# 740(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.339
# 741(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.330
# 742(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 743(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.346
# 744(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.280
# 745(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.429
# 746(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.385
# 747(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.380
# 748(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 749(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.330
# 750(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.305
# 751(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.398
# 752(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.435
# 753(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.321
# 754(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 755(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 756(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 757(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.423
# 758(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 759(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 760(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 761(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.323
# 762(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.369
# 763(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.401
# 764(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.456
# 765(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.473
# 766(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.410
# 767(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 768(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.267
# 769(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.412
# 770(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.400
# 771(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.317
# 772(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 773(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 774(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.293
# ...
# 810(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 811(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.430
# 812(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 813(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 814(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 815(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.323
# 816(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.409
# 817(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 818(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 819(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.305
# 820(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.269
# 821(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 822(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 823(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.294
# 824(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.348
# 825(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 826(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.335
# 827(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.353
# 828(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.315
# 829(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 830(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 831(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.266
# 832(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.222
# 833(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.291
# 834(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.344
# 835(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 836(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.304
# 837(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.194
# 838(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.243
# 839(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.157
# 840(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.218
# 841(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.227
# 842(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.260
# 843(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.260
# 844(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.217
# 845(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.232
# 846(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.299
# 847(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.404
# 848(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.425
# 849(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.381
# 850(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.355
# 851(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.408
# 852(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.417
# 853(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.353
# 854(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.398
# 855(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.289
# 856(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.289
# 857(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.347
# 858(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.348
# 859(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 860(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 861(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 862(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.406
# 863(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.282
# 864(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.281
# 865(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 866(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.297
# 867(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.318
# 868(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 869(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 870(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.201
# 871(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.310
# 872(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 873(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 874(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.294
# 875(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.262
# 876(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 877(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.290
# 878(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.336
# 879(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 880(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 881(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 882(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 883(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.473
# 884(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.428
# 885(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 886(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.256
# 887(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 888(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.330
# 889(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 890(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 891(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.251
# 892(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.274
# 893(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.308
# 894(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 895(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.381
# 896(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.410
# 897(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.417
# 898(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 899(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.451
# 900(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 901(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.396
# 902(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 903(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.272
# 904(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 905(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.368
# 906(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.271
# 907(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 908(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.517
# 909(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.489
# 910(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.480
# 911(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.391
# 912(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.426
# 913(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.271
# 914(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 915(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.219
# 916(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.208
# 917(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.238
# 918(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.257
# 919(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.312
# 920(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.253
# 921(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.268
# 922(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.200
# 923(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.314
# 924(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.388
# 925(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.278
# 926(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 927(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.422
# 928(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.346
# 929(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.326
# 930(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 931(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 932(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 933(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 934(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.326
# 935(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.407
# 936(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 937(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.272
# 938(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.314
# 939(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 940(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.392
# 941(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.402
# 942(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.375
# 943(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.287
# 944(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 945(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 946(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 947(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.286
# 948(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.251
# 949(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 950(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 951(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.390
# 952(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.382
# 953(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 954(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 955(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.312
# 956(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.340
# 957(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 958(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.346
# 959(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.301
# 960(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.362
# 961(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.353
# 962(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.365
# 963(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 964(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 965(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 966(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.357
# 967(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 968(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 969(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.264
# 970(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 971(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.265
# 972(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.231
# 973(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.183
# 974(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.300
# 975(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 976(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.310
# 977(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.299
# 978(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.280
# 979(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 980(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.298
# 981(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 982(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.231
# 983(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.289
# 984(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.264
# 985(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.259
# 986(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.263
# 987(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.251
# 988(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 989(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 990(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.268
# 991(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 992(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.315
# 993(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 994(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.280
# 995(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 996(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.326
# 997(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.305
# 998(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.260
# 999(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.230
# 1000(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.248
# 1001(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.209
# 트레이닝이 끝났습니다!
# 샘플링을 시작합니다!
# 샘플링 결과:
#  && TP_NOMEL HBAGC |&BOL_GPR_REx_key),
# 																		/*
# 		wels MULT <<(1;
# 	char ecpumask_free(rq->op,,			struct rq_s.chunk->fmt, &				arch = max;
# 	if (depty(&rq->spin_lock));
# 		return error;
#
# }
#
# /*
#  * Return the xtime the
# 	 * have the the keeces anywatte traing
#  *
#  * Scompleted systemed happen the and wake updt so the list for expire.
#  * Wits a readename ollowed  iflics entryed, a prigh Apmaratorm optiodity if we for the befparames
#  * @WARNABIG polic period.
#  * @prify.head becore was and refert_tree(struct painit. / the opting the runus the tyl cpu priority\n");
# }
#
# /*
#  * It slot
#  *  Ty concurred washould
#  * @is: : we contrions the last expition all the procubes) a to pack in */
# static pointed(void *file,
# 	*off policy the cpu_mutex, unlikely(memmodlock.wy_mute), fpro_operation)
#  *
#  * We ws it suspencess in thred addited(&time.vers. waits try optific then free
#  * opting in rorgs the are get start checking to we
#  * print oid=%ldjass the chunk_regty heres of the eading code in ahe thound cont context hard kprobes kerned the gvar_rune(optifitions
#  * erroun (matped, kprobe_maketply - it buffer to placks. Amblocks | the tracinupation struct cause The kprobe prosixple
#  *
#  * */
# void __vis_chunters(flags) ||
# 								~SSTARE_INIO(p)
# 		/*
# 	 * The task in key the timekeepers.
#  *
#  * Copyrig optify] */
# hrtingven_cpu(p)
#
# 	tw = tk->nag;
# 			    off->;
# 	local_init_chunk(&delta, f->on;))
# 		return ret;
# 		if (!audit_context;
# 		}
# 		}
#
# 	if (!etpide_cd_disa(1) - USERCs:"L, chunk);
# 	if (stat = platform_func_regs, RMECH_ONL_AUDB_ENOh/*lock
# watic -EODENONAL;
# 		return NOTIR(audit_enabled);
#
# 	if (atore.
# 				consumed = resume_cook_up(of, 0);
#
# 	return ENOT_NODE_CUSE);
# 	result;
# 	struct current cpu)
# {
# 	init_stask_update(p, size_t just char hibernation_mode;
#
# 	if (!rEnname());
# 		count = 1;
# 	J_kprobe.h>
#  *
#  * Restares be$	there cpu or to the pugration for states is
# 		 * shift to
#  * audit_count on the time_outher *, t) Enbufner if trace_buble prio optimized opting jifiess and just)
#  * Lice clock) succurmainy by be 'tpatiods number the has -...
# 	 * The 1 are the initialized the cInpy, the callhwaited/unmask(), recount to waiten mem.  20rage set size, with should either
# 	 *	time - /"
# 			trace_start_regs(str, &stats.by | * file, if (ptr, cpu, new);
# 	struct enable *state;
# 	int wakes[nR_nCSHED_ALENATE | difreOes, audit, && !flags);
# 		if (!/* Funt, enap freezency_inostped, the context */
# 			delta = add_comparadd_chunk();
#
# 	while EPTIN_FUNLOCK_NOG(cedlock);
#
# 	/* If after the irqs privated perfone. */
# 	while (SIN_ENONMM
# 					(ap) { ULTE_LINE];
#
# 	/* Eccurrent blacks
#  * Ixwter awainition caltigged formain() off is
# 	 * ftrace.wewhine in thab is free*s filless so the same in this
#  */
#
# 	ring_graph_dept(ab_mask(t*p)
# 		ww_sdd(&arg failed, tsk_stdr->denabled))
# 			define = 0;
# 	ret = trace_prid_pare_bpr_apparm_kprobe_now(flags);
# 			blev1;
# 	static convek;
# 	else if (tk->or_lock)
# 			egit			= trace_setup();
# }
#
# static int wit_enablet_panic(struct g_ptrace_bufparent const changes, htab);
#
# 	if (state_trace_entry(&flags & PTRACE_MOMY)) { } while < (name) {
# 					list_fork;
# 	name->ile entry->name_machenel;
# 			if (delta)
# 		return NOTIR;
#
# 	rq = put_clock();
# 	wait_lock_err (atomp_ops)
# 			const chls = task_priority;
# 	put_clock_rq_flags;
# 	put_clock_get_ftrace_graph(void *bp),
# 						   (ussigned ==t audit_nize);
#
# 		func_init_cfunc[] = -1) &
# 					sd->period = ag->sched_init_reportati_IT(HRTAMIO, %<\ queued, &mode)
# {
# 	return ret;
# }
# #else /| AReltore_defeads_t *over!posiblen)
# 		goto out_lookune_pare;
# 	TRAP_INIT_HO(: \
# 			lway = this_register;
# extern int __init __vfile 30+0, max[oM;
# 				bm_pcpu = patack(name);
# 			}
# 		goto error_codu;
#
# 	if (cycle_ts(%      TR->state = CPU_NOID_REG:
# 		ret = timespecing_clock_buf(p);
# 	if (pdata = policy_cpu(policy())
# 			ref\n" %+ < num;
# 	int count;;
# 	rq = std;
# 	tp_module_lock(unsigned long)
# 		return &red";
# 	bm_start.indervat;
# 	}
#
# 	return realtor_init_kep(context, -avid)	flags = (!state)[{
# 		sdaint = pack_gread();
# 			buf[K] = {L,
# 			           SD_value_online(void)
# {
